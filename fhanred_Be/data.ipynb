# %%
import pandas as pd

# %%
df = pd.read_csv('./TODOS_USUARIOS_POR_TODOS_LOS_ESTADOS_21_septiembre_2023.csv', encoding='utf-8')
df.head(3)
# Out:
#    ABONADO            NOMBRES/ RAZON SOCIAL    ESTADO TIPO DE PERSONA  \
# 0        1            OCAMPO DURAN, ALVARO     ACTIVO     P. NATURAL
# 1        2  BOTERO LONDOÑO, YENY CLEMENTINA  RETIRADO     P. NATURAL
# 2        3         AGUILERA PIÑEROS, ZENON   RETIRADO     P. NATURAL
#
#   Nº DOCUMENTO TIPO DE VIVIENDA Municipio      Barrio   Direccion  \
# 0     16613915      CASA PROPIA   CUMARAL    GUACAVIA       FINCA
# 1   1010016237   CASA ALQUILADA   CUMARAL  MONSERRATE  CARRERA 16
# 2      3276139      CASA PROPIA   CUMARAL    GUACAVIA     CALLE 7
#
#         NUM-CASA  ... FEC. ING. CONTRATO                VENDEDOR INSTALACION  \
# 0  .KILIAWIRINA   ...         09/03/2021  OFICINA OFICINA, OFICINA RESERVADO
# 1   .10-12 APT 2  ...         10/03/2021  OFICINA OFICINA, OFICINA RESERVADO
# 2        .5 A 33  ...         10/03/2021       VIUCHE GUEVARA, ANGIE NATALIA
#
#   MESES ADEUDADO TIPO DE DOCUMENTO       SEXO ESTADO CUENTA POR CORREO  \
# ...

# %%
df_clear = df.rename(columns={
    'NOMBRES/ RAZON SOCIAL':'name_razon_social',
    'ABONADO': 'n_contrato',
    'ESTADO': 'estado', 
    'TIPO DE PERSONA': 'tipo_persona',  
    'Nº DOCUMENTO': 'n_documento', 
    'TIPO DE VIVIENDA': 'tipo_vivienda', 
    'Municipio': 'municipio', 
    'Barrio':'barrio', 
    'Direccion':'direccion',
    'NUM-CASA': 'n_casa', 
    'REF DIRECCION Y ESTRATO':'estrato', 
    'TEL 1':'tel1', 
    'TEL 2': 'tel2', 
    'TEL 3': 'tel3',
    'FECHA NAC.':'fecha_cumple',
    'E-MAIL': 'email',
    'OS INSTAL':'os_instal', 
    'F INSTAL':'fecha_instal', 
    'SERVICIO INTERNET': 'servicio',
    'DEUDA': 'deuda',
    'DET DEUDA': 'detalle_deuda', 
    'CAJA NAP ': 'caja_nap', 
    'FECHA ULTIMO CORTE':'fecha_ultimo_corte',
    'PAGO ULT MESES': 'ultimo_mes_pago',
    'TARIFA INTERNET': 'plan',
    'PRECIO TARIFA INTERNET': 'precio_tarifa',
    'OS INST INTER': 'os_instal_interno', 
    'FECHA INST': 'fecha_instalacion',
    'OS CORTE INTER':'os_corte_interno',
    'FECHA CORTE INST': 'os_corte_instal',
    'FECHA ULT PAG': 'ultimo_pago', 
    'FEC. ING. CONTRATO': 'inicio_contrato',
    'VENDEDOR INSTALACION': 'vendedor',
    'MESES ADEUDADO':  'mes_adeudado', 
    'TIPO DE DOCUMENTO': 'tipo_documento',
    'SEXO': 'sexo',
    'ESTADO CUENTA POR CORREO' : 'estado_cp_correo',
    'CORREO ENVIO ESTADO CUENTA' : 'correo',
    'REP. CENTRAL RIESGO': 'reporte_c_riesgo',
    'MARCA ONU ':'marca_onu' , 
    'MAC O SERIAL ONU ':'mac'
    })
df_clear.columns
# Out:
# Index(['n_contrato', 'name_razon_social', 'estado', 'tipo_persona',
#        'n_documento', 'tipo_vivienda', 'municipio', 'barrio', 'direccion',
#        'n_casa', 'estrato', 'tel1', 'tel2', 'tel3', 'fecha_cumple', 'email',
#        'os_instal', 'fecha_instal', 'servicio', 'deuda', 'detalle_deuda',
#        'caja_nap', 'fecha_ultimo_corte', 'ultimo_mes_pago', 'plan',
#        'precio_tarifa', 'os_instal_interno', 'fecha_instalacion',
#        'os_corte_interno', 'os_corte_instal', 'ultimo_pago', 'inicio_contrato',
#        'vendedor', 'mes_adeudado', 'tipo_documento', 'sexo',
#        'estado_cp_correo', 'correo', 'reporte_c_riesgo', 'marca_onu', 'mac'],
#       dtype='object')

# %%
df_user = df_clear[[
    'name_razon_social',
    'sexo',
    'tipo_persona',
    'tipo_documento',
    'fecha_cumple',
    'n_documento', 
    'email',
    'n_contrato'
    ]]
df_user
# Out:
#                    name_razon_social       sexo tipo_persona tipo_documento  \
# 0              OCAMPO DURAN, ALVARO   MASCULINO  P. NATURAL              CC
# 1    BOTERO LONDOÑO, YENY CLEMENTINA   FEMENINO  P. NATURAL              CC
# 2           AGUILERA PIÑEROS, ZENON   MASCULINO  P. NATURAL              CC
# 3             MORENO PIÑEROS, NELCY    FEMENINO  P. NATURAL              CC
# 4       ESPEJO SANCHEZ, GLORIA IRENE   FEMENINO  P. NATURAL              CC
# ..                               ...        ...          ...            ...
# 627    AMAYA DUARTE, LLEHINSON FIDEL  MASCULINO  P. NATURAL              CC
# 628     PARRADO GAONA, HEIDY YHUBISA   FEMENINO  P. NATURAL              CC
# 629  RODRIGUEZ MONROY, GLORIA MIRIAM   FEMENINO  P. NATURAL              CC
# 630  LINARES SALCEDO, MARIA ANGELICA   FEMENINO  P. NATURAL              CC
# 631    MORERA MENDEZ, ELINTON AMADEO  MASCULINO  P. NATURAL              CC
#
# ...

# %%
df_contract = df_clear[[
    'n_contrato',
    'estado', 
    'tipo_vivienda', 
    'municipio', 
    'barrio', 
    'direccion',
    'n_casa', 
    'estrato', 
    'tel1', 
    'tel2', 
    'tel3',
    'os_instal', 
    'mac', 
    'servicio',
    'deuda', 
    'detalle_deuda', 
    'caja_nap', 
    'fecha_ultimo_corte',
    'ultimo_mes_pago', 
    'plan', 
    'precio_tarifa',
    'os_instal', 
    'fecha_instal', 
    'os_corte_interno', 
    'fecha_instalacion',
    'ultimo_pago', 
    'inicio_contrato', 
    'vendedor',
    'mes_adeudado', 
    'estado_cp_correo',
    'correo',
    'reporte_c_riesgo', 
    'marca_onu', 
    'mac',
    'n_documento', 
    ]]
df_contract.head(5)
# Out:
#    n_contrato    estado   tipo_vivienda municipio      barrio   direccion  \
# 0           1    ACTIVO     CASA PROPIA   CUMARAL    GUACAVIA       FINCA
# 1           2  RETIRADO  CASA ALQUILADA   CUMARAL  MONSERRATE  CARRERA 16
# 2           3  RETIRADO     CASA PROPIA   CUMARAL    GUACAVIA     CALLE 7
# 3           4    ACTIVO     CASA PROPIA   CUMARAL    GUACAVIA     CALLE 7
# 4           5    ACTIVO  CASA ALQUILADA   CUMARAL    GUACAVIA    GUACAVIA
#
#                   n_casa                                            estrato  \
# 0          .KILIAWIRINA                                           ESTRATO 2
# 1           .10-12 APT 2  USUARIO SOLICITA TRASLADO PARA EL BARRIO MONSE...
# 2                .5 A 33                                          ESTRATO 1
# 3                 .6-251                             EL ENSUEÑO   ESTRATO 1
# 4  .IN TITUCION AGRICOLA                                   EFECTY ESTRATO 2
#
# ...

# %%
df_contract['fecha_cumple'] = pd.to_datetime(df_user['fecha_cumple'], format='%d/%m/%Y')

# Cambia el formato de las fechas en la columna
df_contract['fecha_cumple'] = df_contract['fecha_cumple'].dt.strftime('%Y-%m-%d')

df_contract
# Out:
# /tmp/ipykernel_15820/1560124756.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_user['fecha_cumple'] = pd.to_datetime(df_user['fecha_cumple'], format='%d/%m/%Y')
# /tmp/ipykernel_15820/1560124756.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_user['fecha_cumple'] = df_user['fecha_cumple'].dt.strftime('%Y-%m-%d')
#                    name_razon_social       sexo tipo_persona tipo_documento  \
# 0              OCAMPO DURAN, ALVARO   MASCULINO  P. NATURAL              CC
# ...

# %%
df_json = pd.read_json('./users.json')

# Supongamos que 'fecha_nacimiento' es el nombre de la columna que contiene las fechas


# Guarda el DataFrame de vuelta en el archivo JSON



df_json.head()
# Out:
#                  name_razon_social       sexo tipo_persona tipo_documento  \
# 0            OCAMPO DURAN, ALVARO   MASCULINO  P. NATURAL              CC
# 1  BOTERO LONDOÑO, YENY CLEMENTINA   FEMENINO  P. NATURAL              CC
# 2         AGUILERA PIÑEROS, ZENON   MASCULINO  P. NATURAL              CC
# 3           MORENO PIÑEROS, NELCY    FEMENINO  P. NATURAL              CC
# 4     ESPEJO SANCHEZ, GLORIA IRENE   FEMENINO  P. NATURAL              CC
#
#   fecha_cumple n_documento                       email  n_contrato
# 0   1958-12-15    16613915      AOCAMPODURAN@GMAIL.COM           1
# 1   1995-10-25  1010016237       YENYBOTERO7@GMAIL.COM           2
# 2   1971-08-28     3276139  ZENON.AGUILERA@HOTMAIL.COM           3
# 3   1956-06-04    21238479         MYMOPI.MM@GMAIL.COM           4
# 4   1987-10-07  1119887083      GLO_IRE_ES@HOTMAIL.COM           5
